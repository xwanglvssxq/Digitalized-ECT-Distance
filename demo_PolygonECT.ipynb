# %%
from PolygonECT import com_ECT
import numpy as np

# %%
v = [0,0,1]
D = np.arange(30, 40, 10)
Z = []
file1 = 'octahedron.off'
file2 = 'octahedron.off'
for i in D:
    d = com_ECT(i, v, file1, file2)
    print(f'deg={i}, ECT=', d/(8*np.pi))
    Z.append(d/(8*np.pi))
# Out:
# deg=30, ECT= 0.08018580956165375

# %%
import timeit

time = timeit.timeit('com_ECT(0, [0,0,1], file1, file2)', globals=globals(), number=1)
print(f"time: {time} seconds")
# Out:
# time: 0.5191948670035345 seconds

# %%
import cProfile
import re

cProfile.run('com_ECT(30, [0,0,1], file1, file2)')
# Out:
#          338131 function calls (333559 primitive calls) in 1.110 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        12    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(any)
#       240    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(argsort)
#       560    0.001    0.000    0.010    0.000 <__array_function__ internals>:177(around)
#       152    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(atleast_2d)
#       488    0.001    0.000    0.022    0.000 <__array_function__ internals>:177(clip)
#       188    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(concatenate)
#       312    0.000    0.000    0.027    0.000 <__array_function__ internals>:177(cross)
#        60    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(delete)
# ...
